# %%
# !git clone https://github.com/stark-akib/vision-transformers-cifar10.git
# Out:
# Cloning into 'vision-transformers-cifar10'...
# remote: Enumerating objects: 302, done.
# remote: Counting objects: 100% (168/168), done.
# remote: Compressing objects: 100% (60/60), done.
# remote: Total 302 (delta 143), reused 114 (delta 108), pack-reused 134 (from 2)
# Receiving objects: 100% (302/302), 89.65 KiB | 14.94 MiB/s, done.
# Resolving deltas: 100% (173/173), done.

# %%
# %cd vision-transformers-cifar10
# Out:
# /content/vision-transformers-cifar10

# %%
# train with pretrained vit base
# !python train_cifar10.py --net vit_timm --n_epochs 100 --bs 96
# Out:
# wandb: Currently logged in as: as8751 (akib-r) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.11
# wandb: Run data is saved locally in /content/vision-transformers-cifar10/wandb/run-20250516_011029-nwd1m7p3
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vit_timm_lr0.0001_cifar10
# wandb: ⭐️ View project at https://wandb.ai/akib-r/cifar-challenge
# wandb: 🚀 View run at https://wandb.ai/akib-r/cifar-challenge/runs/nwd1m7p3
# ==> Preparing data..
# ==> Building model..
# cuda
# /content/vision-transformers-cifar10/train_cifar10.py:277: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=use_amp)
#
# Epoch: 0
# ...

# %%
# !gdown 13w10PcsOBigvdFmaGI_MnisbZfH_OzEM -O imagenet100.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=13w10PcsOBigvdFmaGI_MnisbZfH_OzEM
# From (redirected): https://drive.google.com/uc?id=13w10PcsOBigvdFmaGI_MnisbZfH_OzEM&confirm=t&uuid=f5a752c1-78c6-4b83-b0ab-093644b95dc1
# To: /content/vision-transformers-cifar10/imagenet100.zip
# 100% 17.3G/17.3G [04:12<00:00, 68.4MB/s]

# %%
# !unzip imagenet100.zip -d datasets/
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: datasets/imagenet100/val/n01443537/ILSVRC2012_val_00049617.JPEG
#   inflating: datasets/imagenet100/val/n01443537/ILSVRC2012_val_00049712.JPEG
#    creating: datasets/imagenet100/val/n01484850/
#   inflating: datasets/imagenet100/val/n01484850/ILSVRC2012_val_00002338.JPEG
#   inflating: datasets/imagenet100/val/n01484850/ILSVRC2012_val_00002752.JPEG
#   inflating: datasets/imagenet100/val/n01484850/ILSVRC2012_val_00004311.JPEG
#   inflating: datasets/imagenet100/val/n01484850/ILSVRC2012_val_00004329.JPEG
#   inflating: datasets/imagenet100/val/n01484850/ILSVRC2012_val_00006491.JPEG
#   inflating: datasets/imagenet100/val/n01484850/ILSVRC2012_val_00008848.JPEG
#   inflating: datasets/imagenet100/val/n01484850/ILSVRC2012_val_00014467.JPEG
#   inflating: datasets/imagenet100/val/n01484850/ILSVRC2012_val_00015157.JPEG
#   inflating: datasets/imagenet100/val/n01484850/ILSVRC2012_val_00015220.JPEG
# ...

# %%
# !pwd
# Out:
# /content/vision-transformers-cifar10

# %% [markdown]
# # Train ViT on Imagenet100 from Scratch

# %%
# !python train_cifar10.py --dataset imagenet100 --train_dir datasets/imagenet100/train --val_dir datasets/imagenet100/val --net vit --patch 16 --size 224 --n_epochs 10 --bs 32
# Out:
# wandb: Currently logged in as: as8751 (akib-r) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.11
# wandb: Run data is saved locally in /content/vision-transformers-cifar10/wandb/run-20250521_184342-p8u85rm4
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vit_lr0.0001_imagenet100
# wandb: ⭐️ View project at https://wandb.ai/akib-r/cifar-challenge
# wandb: 🚀 View run at https://wandb.ai/akib-r/cifar-challenge/runs/p8u85rm4
# ==> Preparing data..
# ImageNet-100 Classes:
# 0: tench, Tinca tinca
# 1: goldfish, Carassius auratus
# 2: great white shark, white shark, man-eater, man-eating shark, Carcharodon carcharias
# 3: tiger shark, Galeocerdo cuvieri
# 4: hammerhead, hammerhead shark
# 5: electric ray, crampfish, numbfish, torpedo
# 6: stingray
# 7: cock
# 8: hen
# 9: goldfinch, Carduelis carduelis
# 10: indigo bunting, indigo finch, indigo bird, Passerina cyanea
# 11: bulbul
# 12: magpie
# ...

# %% [markdown]
# # Finetune ViT on Imagenet100 from Pretrained model

# %%
# !python train_ViT_transfer_timm.py --dataset imagenet100 --train_dir datasets/imagenet100/train --val_dir datasets/imagenet100/val --net vit_timm --n_epochs 10 --bs 96
# Out:
# wandb: Currently logged in as: as8751 (akib-r) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.19.11
# wandb: Run data is saved locally in /content/vision-transformers-cifar10/wandb/run-20250521_191017-2trumu89
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run vit_timm_lr0.0001_imagenet100
# wandb: ⭐️ View project at https://wandb.ai/akib-r/cifar-challenge
# wandb: 🚀 View run at https://wandb.ai/akib-r/cifar-challenge/runs/2trumu89
# ==> Preparing data..
# ImageNet-100 Classes:
# 0: tench, Tinca tinca
# 1: goldfish, Carassius auratus
# 2: great white shark, white shark, man-eater, man-eating shark, Carcharodon carcharias
# 3: tiger shark, Galeocerdo cuvieri
# 4: hammerhead, hammerhead shark
# 5: electric ray, crampfish, numbfish, torpedo
# 6: stingray
# 7: cock
# 8: hen
# 9: goldfinch, Carduelis carduelis
# 10: indigo bunting, indigo finch, indigo bird, Passerina cyanea
# 11: bulbul
# 12: magpie
# ...

# %% [markdown]
# # Train ViT on Imagenet100 from Scratch with Padnet

# %%
# !python train_ViT_Scratch_padnet.py --dataset imagenet100 --net vit --train_dir datasets/imagenet100/train --val_dir datasets/imagenet100/val --patch 16 --size 224 --n_epochs 10 --bs 128

# %%
#--dataset imagenet100 --train_dir datasets/imagenet100/train --val_dir datasets/imagenet100/val --net vit --patch 16 --size 224 --n_epochs 10 --bs 32
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600 ~/.kaggle/kaggle.json

# %%
#!/bin/bash only working link to download
# !curl -L -o /content/drive/MyDrive/imagenet100/imagenet100.zip\
  https://www.kaggle.com/api/v1/datasets/download/ambityga/imagenet100
